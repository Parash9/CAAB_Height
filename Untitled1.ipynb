# %% [markdown]
# <a href="https://colab.research.google.com/github/Parash9/CAAB_Height/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math # Not strictly needed for basic ops, but good practice if expanding

def calculator():
    """Runs a simple command-line calculator."""

        print("Simple Python Calculator")
            print("Enter 'quit' at any prompt to exit.")

                while True:
                        # --- Get First Number ---
                                try:
                                            num1_input = input("Enter first number: ")
                                                        if num1_input.lower() == 'quit':
                                                                        break
                                                                                    num1 = float(num1_input) # Convert input to float for decimal support
                                                                                            except ValueError:
                                                                                                        print("Invalid input. Please enter a number.")
                                                                                                                    continue # Ask for the first number again

                                                                                                                            # --- Get Operator ---
                                                                                                                                    op = input("Enter operator (+, -, *, /): ")
                                                                                                                                            if op.lower() == 'quit':
                                                                                                                                                        break
                                                                                                                                                                if op not in ('+', '-', '*', '/'):
                                                                                                                                                                            print("Invalid operator. Please use +, -, *, or /.")
                                                                                                                                                                                        continue # Ask for operator again

                                                                                                                                                                                                # --- Get Second Number ---
                                                                                                                                                                                                        try:
                                                                                                                                                                                                                    num2_input = input("Enter second number: ")
                                                                                                                                                                                                                                if num2_input.lower() == 'quit':
                                                                                                                                                                                                                                                break
                                                                                                                                                                                                                                                            num2 = float(num2_input) # Convert input to float
                                                                                                                                                                                                                                                                    except ValueError:
                                                                                                                                                                                                                                                                                print("Invalid input. Please enter a number.")
                                                                                                                                                                                                                                                                                            continue # Ask for the second number again

                                                                                                                                                                                                                                                                                                    # --- Perform Calculation ---
                                                                                                                                                                                                                                                                                                            result = None
                                                                                                                                                                                                                                                                                                                    if op == '+':
                                                                                                                                                                                                                                                                                                                                result = num1 + num2
                                                                                                                                                                                                                                                                                                                                        elif op == '-':
                                                                                                                                                                                                                                                                                                                                                    result = num1 - num2
                                                                                                                                                                                                                                                                                                                                                            elif op == '*':
                                                                                                                                                                                                                                                                                                                                                                        result = num1 * num2
                                                                                                                                                                                                                                                                                                                                                                                elif op == '/':
                                                                                                                                                                                                                                                                                                                                                                                            if num2 == 0:
                                                                                                                                                                                                                                                                                                                                                                                                            print("Error: Division by zero is not allowed.")
                                                                                                                                                                                                                                                                                                                                                                                                                            continue # Skip printing result and start next calculation
                                                                                                                                                                                                                                                                                                                                                                                                                                        else:
                                                                                                                                                                                                                                                                                                                                                                                                                                                        result = num1 / num2

                                                                                                                                                                                                                                                                                                                                                                                                                                                                # --- Display Result ---
                                                                                                                                                                                                                                                                                                                                                                                                                                                                        if result is not None:
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    # Format nicely, removing trailing .0 for whole numbers if possible
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                if result == int(result):
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 print(f"Result: {num1} {op} {num2} = {int(result)}")
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             else:
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              print(f"Result: {num1} {op} {num2} = {result:.4f}") # Format floats

                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      print("-" * 20) # Separator for next calculation

                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          print("Calculator exited.")

                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          # --- Run the calculator ---
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          if __name__ == "__main__":
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              calculator()
# Out:
#   File "<ipython-input-1-cb12ec8597db>", line 6
#     print("Simple Python Calculator")
#     ^
# IndentationError: unexpected indent
